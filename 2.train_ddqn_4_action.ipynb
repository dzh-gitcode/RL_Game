# %%
# 导入相关库
import matplotlib.pyplot as plt
import numpy as np

import copy
import os
import random
from collections import deque

import torch

import gym
import gym_super_mario_bros
from gym.spaces import Box
from gym.wrappers import FrameStack


from nes_py.wrappers import JoypadSpace
from torch import nn
from torchvision import transforms

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True' 

# 使用GPU
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
# 初始化马里奥环境: https://pypi.org/project/gym-super-mario-bros/

# SuperMarioBros-<world>-<stage>-v<version>

# <world> is a number in {1, 2, 3, 4, 5, 6, 7, 8} indicating the world
# <stage> is a number in {1, 2, 3, 4} indicating the stage within a world
# <version> is a number in {0, 1, 2, 3} specifying the ROM mode to use
    # 0: standard ROM
    # 1: downsampled ROM
    # 2: pixel ROM
    # 3: rectangle ROM
    
env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')

# 限制 Action-space（所有可能出现的动作）：向左、向左跳、向右、向右跳
env = JoypadSpace(env, [["left"],["left", "A"],["right"], ["right", "A"]])

# env = JoypadSpace(env, [["right"], ["right", "A"]])

# %%
# 初始化环境，重置环境，并返回当前State
obs = env.reset()

# %%
obs.shape
# Out:
# (240, 256, 3)

# %%
# 绘制
plt.imshow(obs)
plt.axis("off")
# Out:
# (-0.5, 255.5, 239.5, -0.5)

# %%
# Agent做出一个动作，环境返回下一时刻的状态、奖励、是否结束、其他信息
# step的参数Action：action-sapce中的动作索引
obs, reward, done, info = env.step(action=3)

# %%
obs.shape, reward, done, info
# Out:
# ((240, 256, 3),
#  0.0,
#  False,
#  {'coins': 0,
#   'flag_get': False,
#   'life': 2,
#   'score': 0,
#   'stage': 1,
#   'status': 'small',
#   'time': 400,
#   'world': 1,
#   'x_pos': 40,
#   'y_pos': 79})

# %%
plt.imshow(obs)
plt.axis("off")
# Out:
# (-0.5, 255.5, 239.5, -0.5)

# %%
# 多运行几次，可以看到Mario向右上角运动
for i in range(10):
    obs, reward, done, info = env.step(action=3)
plt.imshow(obs)
plt.axis("off")
# Out:
# (-0.5, 255.5, 239.5, -0.5)

# %%
# 预处理环境
# 原始游戏的图像的大小为：(240, 256, 3)，在传给网络前需要过滤掉一些不用的信息（如画面的颜色信息）
# 使用gym.Wrapper模块进行预处理，可以自定义类（需要继承gym.Wrapper）

# %%
# 因为连续多个帧画面之间区别不大，可以间隔一些帧采样提高效率，主要重写了 step 函数
# 但是Reward需要累加再返回
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip, verbose_reward=False):
        super().__init__(env)
        self._skip = skip
        self.verbose_reward = verbose_reward
        self._last_x_pos = None
        self._last_time = None

    def reset(self, **kwargs):
        self._last_x_pos = None
        self._last_time = None
        return self.env.reset(**kwargs)

    def _estimate_reward_terms(self, info, done):
        x_pos = info.get("x_pos")
        time_left = info.get("time")

        if self._last_x_pos is None:
            self._last_x_pos = x_pos
        if self._last_time is None:
            self._last_time = time_left

        x_delta = x_pos - self._last_x_pos
        x_reward = 0 if (x_delta < -5 or x_delta > 5) else x_delta

        time_delta = time_left - self._last_time
        time_penalty = 0 if time_delta > 0 else time_delta

        death_penalty = -25 if (done and not info.get("flag_get", False)) else 0

        self._last_x_pos = x_pos
        self._last_time = time_left

        return x_reward, time_penalty, death_penalty

    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward

            if self.verbose_reward:
                x_reward, time_penalty, death_penalty = self._estimate_reward_terms(info, done)
                estimated_sum = x_reward + time_penalty + death_penalty
                print(
                    f"[RewardDebug] inner_step={i+1}/{self._skip} "
                    f"reward={reward:+.2f} | x={x_reward:+.2f} time={time_penalty:+.2f} "
                    f"death={death_penalty:+.2f} est_sum={estimated_sum:+.2f} "
                    f"x_pos={info.get('x_pos')} time={info.get('time')} "
                    f"done={done} flag_get={info.get('flag_get')}"
                )

            if done:
                break
        return obs, total_reward, done, info


# 将画面转为灰度图
# 通道顺序调整[H, W, C]  to [C, H, W]，处理后大小：[1, 240, 256]
class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = Box(low=0, high=255, shape=self.observation_space.shape[:2], dtype=np.uint8)

    def observation(self, observation):
        transform = transforms.Grayscale()
        return transform(torch.tensor(np.transpose(observation, (2, 0, 1)).copy(), dtype=torch.float))

# 缩放，处理后大小 [1, 84, 84]
class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        self.shape = (shape, shape)
        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transformations = transforms.Compose([transforms.Resize(self.shape), transforms.Normalize(0, 255)])
        return transformations(observation).squeeze(0)

# %%
# 对画面进行调整，处理完大小：(1, 84, 84)
# 打开后会打印每个 inner step 的 reward 分解（x/time/death）
reward_debug = True
env = SkipFrame(env, skip=4, verbose_reward=reward_debug)
env = GrayScaleObservation(env)
env = ResizeObservation(env, shape=84)

# 打包最新的4帧画面，大小：(4, 84, 84)，打包4帧的原因是为了让Agent能够感知到Mario的运动方向，因为单帧画面无法感知到运动方向。需要运动方向的信息才能更好的学习到游戏规则
env = FrameStack(env, num_stack=4)
    

# 随机种子
env.seed(42)
env.action_space.seed(42)
torch.manual_seed(42)
torch.random.manual_seed(42)
random.seed(42)
np.random.seed(42)

# %%
# 重置
obs = env.reset()

# %%
# 可以看到状态变了
obs.shape
# Out:
# (4, 84, 84)

# %%
# 多运行几次，可以看到Mario向右上角运动
for i in range(10):
    obs, reward, done, info = env.step(action=3)
print(obs.shape)

# 绘制这4帧
plt.figure(figsize=(20, 20))
for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.imshow(obs[i], cmap="gray")
    plt.axis("off")
# Out:
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=41 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=41 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=42 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=42 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=43 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=44 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=44 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=45 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=46 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=47 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=48 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=49 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=50 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=51 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=53 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=54 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=55 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=57 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=58 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=60 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=61 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=63 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=65 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=67 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=68 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=70 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=72 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=74 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=75 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=77 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=79 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=81 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=82 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=84 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=86 time=398 done=False flag_get=False
# (4, 84, 84)

# %%
# 这样预处理完毕，每次Agent做完一个Action，Environment会返回(4, 84, 84)这样的一个State（4张相邻画面的灰度图）

# %% [markdown]
# ![](https://enpei-md.oss-cn-hangzhou.aliyuncs.com/img202309042352782.png?x-oss-process=style/wp)

# %%
# Double deep Q-Network 定义
class DDQNSolver(nn.Module):
    # CNN架构：input -> (conv2d + relu) x 3 -> flatten -> (dense + relu) x 2 -> output
    
    def __init__(self, output_dim):
        super().__init__()
        # 定义Online network
        self.online = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim),
        )
        # 定义Target network（直接复制Online network）
        self.target = copy.deepcopy(self.online)
        # 将target network参数冻结
        for p in self.target.parameters():
            p.requires_grad = False

    def forward(self, input, model):
        if model == "online":
            return self.online(input)
        elif model == "target":
            return self.target(input)


# Agent执行的类，主要有4个功能
# act函数：基于当前状态返回对应的动作ID
# remember函数：Agent需要缓存之前的一些信息来更新动作策略（state, next_state, action, reward, done）
# recall函数：回忆之前缓存的信息
# experience_replay：经验回放、学习
class DDQNAgent:
    def __init__(self, action_dim, save_directory):
        self.action_dim = action_dim
        self.save_directory = save_directory
        if not os.path.exists(self.save_directory):
            os.makedirs(self.save_directory)
        self.net = DDQNSolver(self.action_dim).to(device)
        self.exploration_rate = 1.0 # 控制探索和利用的概率
        self.exploration_rate_decay = 0.99
        self.exploration_rate_min = 0.01
        self.current_step = 0
        self.memory = deque(maxlen=100000)
        self.batch_size = 32
        self.gamma = 0.95
        self.sync_period = 1e4
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=0.00025, eps=1e-4)
        self.loss = torch.nn.SmoothL1Loss()
        self.episode_rewards = []
        self.moving_average_episode_rewards = []
        self.current_episode_reward = 0.0

    def log_episode(self):
        self.episode_rewards.append(self.current_episode_reward)
        self.current_episode_reward = 0.0

    def log_period(self, episode, epsilon, step):
        self.moving_average_episode_rewards.append(np.round(np.mean(self.episode_rewards[-checkpoint_period:]), 3))
        print(f"Episode {episode} - Step {step} - Epsilon {epsilon} - Mean Reward {self.moving_average_episode_rewards[-1]}")
        plt.plot(self.moving_average_episode_rewards)
        plt.savefig(os.path.join(self.save_directory, f"episode_rewards_plot_{episode}.png"))
        plt.clf()

    # remember函数：Agent需要缓存之前的一些信息来更新动作策略（state, next_state, action, reward, done）
    def remember(self, state, next_state, action, reward, done):
        self.memory.append((torch.tensor(state.__array__()), torch.tensor(next_state.__array__()),
                            torch.tensor([action]), torch.tensor([reward]), torch.tensor([done])))
    
    # 经验回放、学习
    def experience_replay(self, step_reward):
        self.current_episode_reward += step_reward  # 更新当前回合的奖励

        # 在一定的步数间隔内，将Target网络与Online网络同步参数
        if self.current_step % self.sync_period == 0:
            self.net.target.load_state_dict(self.net.online.state_dict())

        # 如果批处理大小大于记忆体中的样本数量，返回（样本不足）
        if self.batch_size > len(self.memory):
            return

        # 获取记忆中数据
        state, next_state, action, reward, done = self.recall()

        # 从Online网络获取预测 Q 值
        q_estimate = self.net(state.to(device), model="online")[np.arange(0, self.batch_size), action.to(device)]

        # 使用目标网络计算目标 Q 值，无需更新参数
        with torch.no_grad():
            # 最优动作
            best_action = torch.argmax(self.net(next_state.to(device), model="online"), dim=1)
            # 新状态下最大Q
            next_q = self.net(next_state.to(device), model="target")[np.arange(0, self.batch_size), best_action]
            # 目标Q值（使用done区分游戏是否结束，0、1分别表示未结束、已结束）
            q_target = (reward.to(device) + (1 - done.to(device).float()) * self.gamma * next_q  ).float()

        # 计算损失
        loss = self.loss(q_estimate, q_target)
        # 执行反向传播并更新在线网络
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()



    # recall函数：回忆之前缓存的信息（随机采样）
    def recall(self):
        state, next_state, action, reward, done = map(torch.stack, zip(*random.sample(self.memory, self.batch_size)))
        return state, next_state, action.squeeze(), reward.squeeze(), done.squeeze()

    # act函数：基于当前状态和最优动作策略（optimaloptimal action policy）返回对应的动作ID
    def act(self, state):
        # 随机动作（探索和利用概率）
        if np.random.rand() < self.exploration_rate:
            action = np.random.randint(self.action_dim)
        # 根据策略执行动作
        else:
            # 将图像数据输入网络 4,84，84 -> 1,4,84,84
            action_values = self.net(torch.tensor(state.__array__()).to(device).unsqueeze(0), model="online")
            # 获取动作ID
            action = torch.argmax(action_values, dim=1).item()

        # 降低 exploration_rate
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)
        # 增加步数
        self.current_step += 1
        return action

    # 加载权重
    def load_checkpoint(self, path):
        checkpoint = torch.load(path, map_location='cpu')
        self.net.load_state_dict(checkpoint['model'])
        self.exploration_rate = checkpoint['exploration_rate']

    # 保存权重
    def save_checkpoint(self):
        filename = os.path.join(self.save_directory, 'checkpoint_{}.pth'.format(episode))
        torch.save(dict(model=self.net.state_dict(), exploration_rate=self.exploration_rate), f=filename)
        print('Checkpoint saved to \'{}\''.format(filename))

# %%
# 权重保存间隔
checkpoint_period = 10

# 保存路径
save_directory = "weights/ddqn/"

# 是否加载预训练权重（True: 继续训练, False: 从头训练）
use_pretrained = False

# 预训练权重文件名（仅在 use_pretrained=True 时生效）
checkpoint_name = "checkpoint_4action_12060.pth"

# 定义网络
agent = DDQNAgent(action_dim=env.action_space.n, save_directory=save_directory)

# 按开关决定是否加载
if use_pretrained:
    agent.load_checkpoint(os.path.join(save_directory, checkpoint_name))

# %%
# 训练步骤：
# 1.初始化Q值
# 2.基于当前状态，执行动作
# 3.环境更新到下一状态，获得奖励
# 4.更新网络参数
    # 4.1 记忆之前的信息
    # 4.2 经验回放、学习
# 5.重复2-4步骤


# 启动训练
episode = 0
while True:
    # 初始化
    state = env.reset()
    while True:
        # DDQN 推理得到动作
        action = agent.act(state)
        # GYM渲染显示（AutoDL等云主机训练时，注释这段代码）
        env.render()
        # GYM返回新状态信息
        next_state, reward, done, info = env.step(action)
        # DDQN记忆参数
        agent.remember(state, next_state, action, reward, done)
        # DDQN学习
        agent.experience_replay(reward)
        
        state = next_state
        # 判断是否结束（闯关、死亡都算结束）
        if done:
            episode += 1
            agent.log_episode()
            if episode % checkpoint_period == 0:
                # 记录曲线
                agent.log_period(episode=episode, epsilon=agent.exploration_rate, step=agent.current_step)
                # 保存权重
                agent.save_checkpoint()
            break
# Out:
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=38 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=39 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=41 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=42 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=43 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=44 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=46 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=47 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=49 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=50 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=52 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=54 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=55 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=57 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=58 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=59 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=61 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=62 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=64 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=65 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=67 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=68 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=69 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=70 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=71 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=73 time=398 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=74 time=398 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=76 time=398 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=77 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=79 time=398 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=81 time=398 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=82 time=398 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=84 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=85 time=398 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=86 time=398 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=88 time=398 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=89 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=89 time=398 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=90 time=398 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=91 time=398 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=92 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=93 time=398 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=94 time=398 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=95 time=398 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=96 time=397 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=98 time=397 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=99 time=397 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=100 time=397 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=102 time=397 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=103 time=397 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=105 time=397 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=106 time=397 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=108 time=397 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=109 time=397 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=110 time=397 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=112 time=397 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=113 time=397 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=115 time=397 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=116 time=397 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=118 time=397 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=120 time=397 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=121 time=397 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=123 time=397 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=125 time=397 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=127 time=396 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=128 time=396 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=130 time=396 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=132 time=396 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=134 time=396 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=135 time=396 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=137 time=396 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=139 time=396 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=140 time=396 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=142 time=396 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=143 time=396 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=145 time=396 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=146 time=396 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=148 time=396 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=150 time=396 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=151 time=396 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=153 time=396 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=155 time=396 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=157 time=396 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=158 time=396 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=160 time=395 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=161 time=395 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=162 time=395 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=163 time=395 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=164 time=395 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=165 time=395 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=166 time=395 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=167 time=395 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=168 time=395 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=169 time=395 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=170 time=395 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=172 time=395 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=173 time=395 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=175 time=395 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=177 time=395 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=178 time=395 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=180 time=395 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=182 time=395 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=184 time=395 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=185 time=395 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=187 time=394 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=188 time=394 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=190 time=394 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=191 time=394 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=193 time=394 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=194 time=394 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=195 time=394 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=196 time=394 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=198 time=394 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=199 time=394 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=200 time=394 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=201 time=394 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=201 time=394 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=202 time=394 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=203 time=394 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=204 time=394 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=204 time=394 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=205 time=394 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=205 time=394 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=206 time=394 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=206 time=393 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=207 time=393 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=207 time=393 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=207 time=393 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=207 time=393 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=208 time=393 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=208 time=393 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=209 time=393 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=210 time=393 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=210 time=393 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=211 time=393 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=212 time=393 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=213 time=393 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=214 time=393 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=215 time=393 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=216 time=393 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=217 time=393 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=218 time=393 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=219 time=393 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=220 time=393 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=222 time=392 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=223 time=392 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=224 time=392 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=225 time=392 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=226 time=392 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=226 time=392 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=227 time=392 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=228 time=392 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=229 time=392 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=230 time=392 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=231 time=392 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=232 time=391 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=234 time=391 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=235 time=391 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=237 time=391 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=239 time=391 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=241 time=391 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=242 time=391 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=244 time=391 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=245 time=391 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=247 time=391 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=248 time=391 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=249 time=391 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=251 time=391 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=252 time=391 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=254 time=391 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=255 time=391 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=257 time=391 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=258 time=391 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=259 time=391 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=260 time=391 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=262 time=390 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=263 time=390 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=265 time=390 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=266 time=390 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=268 time=390 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=269 time=390 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=271 time=390 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=273 time=390 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=274 time=390 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=276 time=390 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=278 time=390 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=280 time=390 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=281 time=390 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=283 time=390 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=285 time=390 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=287 time=390 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=288 time=390 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=290 time=390 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=292 time=390 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=294 time=390 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=295 time=389 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=297 time=389 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=299 time=389 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=301 time=389 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=302 time=389 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=304 time=389 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=306 time=389 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=308 time=389 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=309 time=389 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=311 time=389 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=313 time=389 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=315 time=389 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=316 time=389 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=318 time=389 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=320 time=389 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=322 time=389 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=323 time=389 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=325 time=389 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=327 time=389 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=329 time=389 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=330 time=388 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=332 time=388 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=334 time=388 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=336 time=388 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=337 time=388 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=339 time=388 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=340 time=388 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=341 time=388 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=343 time=388 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=344 time=388 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=346 time=388 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=348 time=388 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=349 time=388 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=351 time=388 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=353 time=388 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=355 time=388 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=356 time=388 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=358 time=388 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=360 time=388 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=362 time=388 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=363 time=387 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=365 time=387 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=367 time=387 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=369 time=387 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=370 time=387 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=372 time=387 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=374 time=387 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=376 time=387 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=377 time=387 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=379 time=387 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=380 time=387 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=381 time=387 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=383 time=387 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=384 time=387 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=386 time=387 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=388 time=387 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=390 time=387 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=391 time=387 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=393 time=387 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=395 time=387 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=397 time=386 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=398 time=386 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=400 time=386 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=402 time=386 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=403 time=386 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=405 time=386 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=406 time=386 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=408 time=386 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=410 time=386 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=411 time=386 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=413 time=386 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=415 time=386 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=417 time=386 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=418 time=386 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=420 time=386 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=422 time=386 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=423 time=386 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=425 time=386 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=426 time=386 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=428 time=386 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=430 time=385 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=431 time=385 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=433 time=385 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=385 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=434 time=384 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=433 time=384 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=433 time=384 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=433 time=384 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=433 time=383 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=432 time=383 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=431 time=383 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=430 time=383 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=430 time=383 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=428 time=383 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=427 time=383 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=426 time=383 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=425 time=383 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=423 time=383 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=421 time=383 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=420 time=383 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=418 time=383 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=416 time=383 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=414 time=383 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=413 time=383 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=411 time=383 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=409 time=383 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=-2.00 | x=-2.00 time=+0.00 death=+0.00 est_sum=-2.00 x_pos=407 time=383 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=-1.00 | x=-1.00 time=+0.00 death=+0.00 est_sum=-1.00 x_pos=406 time=383 done=False flag_get=False
# ...
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=358 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=357 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=356 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=722 time=355 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=-1.00 | x=+0.00 time=-1.00 death=+0.00 est_sum=-1.00 x_pos=722 time=354 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=-15.00 | x=+0.00 time=+0.00 death=-25.00 est_sum=-25.00 x_pos=722 time=354 done=True flag_get=False
# Episode 30 - Step 2987 - Epsilon 0.01 - Mean Reward 459.8
# Checkpoint saved to 'weights/ddqn/checkpoint_30.pth'
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=40 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=41 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=41 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=42 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=42 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=43 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=44 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+0.00 | x=+0.00 time=+0.00 death=+0.00 est_sum=+0.00 x_pos=44 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=45 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=46 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=47 time=400 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=48 time=400 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=49 time=400 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=50 time=400 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+0.00 | x=+1.00 time=-1.00 death=+0.00 est_sum=+0.00 x_pos=51 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=53 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=54 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=55 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=57 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=58 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=60 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=61 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=63 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=65 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=67 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=68 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=70 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=72 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=74 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=75 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=77 time=399 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=79 time=399 done=False flag_get=False
# [RewardDebug] inner_step=1/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=81 time=399 done=False flag_get=False
# [RewardDebug] inner_step=2/4 reward=+1.00 | x=+1.00 time=+0.00 death=+0.00 est_sum=+1.00 x_pos=82 time=399 done=False flag_get=False
# [RewardDebug] inner_step=3/4 reward=+1.00 | x=+2.00 time=-1.00 death=+0.00 est_sum=+1.00 x_pos=84 time=398 done=False flag_get=False
# [RewardDebug] inner_step=4/4 reward=+2.00 | x=+2.00 time=+0.00 death=+0.00 est_sum=+2.00 x_pos=86 time=398 done=False flag_get=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 26
#      24 agent.remember(state, next_state, action, reward, done)
#      25 # DDQN学习
# ---> 26 agent.experience_replay(reward)
#      28 state = next_state
#      29 # 判断是否结束（闯关、死亡都算结束）
#
# Cell In[52], line 91, in DDQNAgent.experience_replay(self, step_reward)
#      88 state, next_state, action, reward, done = self.recall()
#      90 # 从Online网络获取预测 Q 值
# ---> 91 q_estimate = self.net(state.to(device), model="online")[np.arange(0, self.batch_size), action.to(device)]
#      93 # 使用目标网络计算目标 Q 值，无需更新参数
#      94 with torch.no_grad():
#      95     # 最优动作
#
# KeyboardInterrupt:

# %%
# 定位 gym_super_mario_bros 底层奖励实现 + 查看当前 wrapper 链
import inspect
import gym_super_mario_bros.smb_env as smb_env

print("smb_env.py 路径:", smb_env.__file__)
print("\n===== SuperMarioBrosEnv._get_reward 源码 =====")
print(inspect.getsource(smb_env.SuperMarioBrosEnv._get_reward))

print("\n===== 当前 env wrapper 链 =====")
current = env
level = 0
while True:
    print(f"{level}: {type(current).__name__}")
    if not hasattr(current, "env"):
        break
    current = current.env
    level += 1
# Out:
# smb_env.py 路径: d:\ProgramData\Anaconda3\envs\rl_game\lib\site-packages\gym_super_mario_bros\smb_env.py
#
# ===== SuperMarioBrosEnv._get_reward 源码 =====
#     def _get_reward(self):
#         """Return the reward after a step occurs."""
#         return self._x_reward + self._time_penalty + self._death_penalty
#
#
# ===== 当前 env wrapper 链 =====
# 0: FrameStack
# 1: ResizeObservation
# 2: GrayScaleObservation
# 3: SkipFrame
# 4: JoypadSpace
# 5: TimeLimit
# 6: SuperMarioBrosEnv
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
